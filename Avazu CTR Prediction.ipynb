# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})
np.random.seed(9221999)

tp = pd.read_csv('./sample_data/train.csv', dtype=unicode, iterator=True, chunksize=1000)
train_df = pd.concat(list(tp), ignore_index=True)

# %%
train_df.head()
# Out:
#                      id click      hour    C1 banner_pos   site_id  \
# 0   1000009418151094273     0  14102100  1005          0  1fbe01fe
# 1  10007197383452514432     0  14102100  1005          0  1fbe01fe
# 2  10013750748974177308     0  14102100  1005          0  1fbe01fe
# 3  10017891063419751227     0  14102100  1005          0  ceea3181
# 4  10022961149355219548     0  14102100  1005          0  85f751fd
#
#   site_domain site_category    app_id app_domain app_category device_id  \
# 0    f3845767      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 1    f3845767      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 2    f3845767      28905ebd  ecad2386   7801e8d9     07d7df22  a99f214a
# 3    6225315b      f028772b  ecad2386   7801e8d9     07d7df22  a99f214a
# 4    c4e18dd6      50e219e0  e2fcccd2   5c5a694b     0f2161f8  bd7c02a1
#
#   device_ip device_model device_type device_conn_type    C14  C15 C16   C17  \
# ...

# %%
train_df[['C14','C15','C16','C17','C18','C19','C20','C21']].head()
# Out:
#      C14  C15 C16   C17 C18 C19     C20 C21
# 0  15706  320  50  1722   0  35      -1  79
# 1  15704  320  50  1722   0  35  100084  79
# 2  15703  320  50  1722   0  35  100083  79
# 3  15702  320  50  1722   0  35  100084  79
# 4   4687  320  50   423   2  39  100148  32
#
# [5 rows x 8 columns]

# %%
sns.barplot(train_df['C15'])

# %%
sns.barplot(train_df['C16'])

# %%
sns.barplot(train_df['C17'])

# %%
sns.barplot(train_df['C18'])

# %%
sns.barplot(train_df['C19'])

# %%
sns.barplot(train_df['C20'])

# %%
sns.barplot(train_df['C21'])
